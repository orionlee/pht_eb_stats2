# %% [markdown]
# # PHT EB Candidates Browser

# %%
from importlib import reload

from IPython.display import display, HTML, clear_output

import numpy as np

import pandas as pd
from pandas.io.clipboard import clipboard_set

import matplotlib.pyplot as plt

import catalog
import catalog_stats
import dashboard_utils
from dashboard_utils import CAT_COLS_COMMON
from dashboard_utils import two_columns

display(HTML("<style>.container { width:99% !important; }</style>"))
# Out:
# <style>.container { width:99% !important; }</style>

# %%
df_catalog = dashboard_utils.get_catalog("pht_eb")
print("Num of TICs:", len(df_catalog))
# Out:
# Num of TICs: 12561

# %%
reload(dashboard_utils)

idx_start, page_size = 0, 10

df = df_catalog
df = (
    df
    [(df["is_eb_catalog"] == "F") & (df["eb_score"] >= 3)]  # those listed in other catalogs as something other than EBs
#     [(df["is_eb_catalog"] == "-") & (df["eb_score"] >= 3)]  # those not listed in other catalogs at all
    .sort_values(["eb_score", "tic_id"], ascending=[False, True])
#     .groupby("eb_score_group")
#     .head(2)
#     .sort_values(["eb_score_group"], ascending=[False])
    )

print("Num. of candidates selected:", len(df))
dashboard_utils.style(df[["best_subject_img_id", ] + CAT_COLS_COMMON][idx_start:idx_start + page_size], show_thumbnail=True)
# Out:
# Num. of candidates selected: 173
# <style type="text/css">
# </style>
# <table id="T_af507">
#   <thead>
#     <tr>
#       <th id="T_af507_level0_col0" class="col_heading level0 col0" >best_subject_img_id</th>
#       <th id="T_af507_level0_col1" class="col_heading level0 col1" >tic_id</th>
#       <th id="T_af507_level0_col2" class="col_heading level0 col2" >best_subject_id</th>
#       <th id="T_af507_level0_col3" class="col_heading level0 col3" >is_eb_catalog</th>
#       <th id="T_af507_level0_col4" class="col_heading level0 col4" >eb_score</th>
#       <th id="T_af507_level0_col5" class="col_heading level0 col5" >SIMBAD_MAIN_ID</th>
#       <th id="T_af507_level0_col6" class="col_heading level0 col6" >SIMBAD_OTYPES</th>
#       <th id="T_af507_level0_col7" class="col_heading level0 col7" >SIMBAD_Is_EB</th>
#       <th id="T_af507_level0_col8" class="col_heading level0 col8" >VSX_OID</th>
#       <th id="T_af507_level0_col9" class="col_heading level0 col9" >VSX_Type</th>
#       <th id="T_af507_level0_col10" class="col_heading level0 col10" >VSX_Is_EB</th>
#       <th id="T_af507_level0_col11" class="col_heading level0 col11" >VSX_Period</th>
#       <th id="T_af507_level0_col12" class="col_heading level0 col12" >ASASSN_Name</th>
#       <th id="T_af507_level0_col13" class="col_heading level0 col13" >ASASSN_URL</th>
#       <th id="T_af507_level0_col14" class="col_heading level0 col14" >ASASSN_Type</th>
#       <th id="T_af507_level0_col15" class="col_heading level0 col15" >ASASSN_Per</th>
#       <th id="T_af507_level0_col16" class="col_heading level0 col16" >TESSEB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_af507_row0_col0" class="data row0 col0" ><img src="https://panoptes-uploads.zooniverse.org/subject_location/29929c8b-55e4-42be-a59d-2e487930dcbb.png"></td>
#       <td id="T_af507_row0_col1" class="data row0 col1" ><a target="_exofop" href="https://exofop.ipac.caltech.edu/tess/target.php?id=143669444">143669444</a></td>
#       <td id="T_af507_row0_col2" class="data row0 col2" ><a target="_pht" href="https://www.zooniverse.org/projects/nora-dot-eisner/planet-hunters-tess/talk/subjects/32026607">32026607</a></td>
#       <td id="T_af507_row0_col3" class="data row0 col3" >F</td>
#       <td id="T_af507_row0_col4" class="data row0 col4" >11</td>
#       <td id="T_af507_row0_col5" class="data row0 col5" ><a target="_simbad" href="https://simbad.u-strasbg.fr/simbad/sim-basic?Ident=HD  64881">HD  64881</a></td>
#       <td id="T_af507_row0_col6" class="data row0 col6" ></td>
#       <td id="T_af507_row0_col7" class="data row0 col7" >-</td>
#       <td id="T_af507_row0_col8" class="data row0 col8" ><a target="_vsx" href="https://www.aavso.org/vsx/index.php?view=detail.top&oid=409787">409787</a></td>
#       <td id="T_af507_row0_col9" class="data row0 col9" >ACV|ELL</td>
#       <td id="T_af507_row0_col10" class="data row0 col10" >F</td>
#       <td id="T_af507_row0_col11" class="data row0 col11" >1.103900</td>
#       <td id="T_af507_row0_col12" class="data row0 col12" >J075359.20-453838.0</td>
#       <td id="T_af507_row0_col13" class="data row0 col13" ><a target="_asas_sn" href="https://asas-sn.osu.edu/variables/269523">details</a></td>
#       <td id="T_af507_row0_col14" class="data row0 col14" >VAR</td>
#       <td id="T_af507_row0_col15" class="data row0 col15" >274.249967</td>
#       <td id="T_af507_row0_col16" class="data row0 col16" ><a target="_tesseb" href="http://tessebs.villanova.edu/search_results?tic=143669444">details</a></td>
#     </tr>
#     <tr>
#       <td id="T_af507_row1_col0" class="data row1 col0" ><img src="https://panoptes-uploads.zooniverse.org/subject_location/72320bdd-3dd3-430e-8afe-fe2e75b2c70b.png"></td>
#       <td id="T_af507_row1_col1" class="data row1 col1" ><a target="_exofop" href="https://exofop.ipac.caltech.edu/tess/target.php?id=198537349">198537349</a></td>
#       <td id="T_af507_row1_col2" class="data row1 col2" ><a target="_pht" href="https://www.zooniverse.org/projects/nora-dot-eisner/planet-hunters-tess/talk/subjects/44563986">44563986</a></td>
#       <td id="T_af507_row1_col3" class="data row1 col3" >F</td>
#       <td id="T_af507_row1_col4" class="data row1 col4" >7</td>
#       <td id="T_af507_row1_col5" class="data row1 col5" ><a target="_simbad" href="https://simbad.u-strasbg.fr/simbad/sim-basic?Ident=HD 141988">HD 141988</a></td>
#       <td id="T_af507_row1_col6" class="data row1 col6" ></td>
#       <td id="T_af507_row1_col7" class="data row1 col7" >-</td>
#       <td id="T_af507_row1_col8" class="data row1 col8" ><a target="_vsx" href="https://www.aavso.org/vsx/index.php?view=detail.top&oid=58848">58848</a></td>
#       <td id="T_af507_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_af507_row1_col10" class="data row1 col10" >-</td>
#       <td id="T_af507_row1_col11" class="data row1 col11" >nan</td>
#       <td id="T_af507_row1_col12" class="data row1 col12" >J154830.03+622040.8</td>
#       <td id="T_af507_row1_col13" class="data row1 col13" ><a target="_asas_sn" href="https://asas-sn.osu.edu/variables/91051">details</a></td>
#       <td id="T_af507_row1_col14" class="data row1 col14" >ROT:</td>
#       <td id="T_af507_row1_col15" class="data row1 col15" >0.000000</td>
#       <td id="T_af507_row1_col16" class="data row1 col16" ><a target="_tesseb" href="http://tessebs.villanova.edu/search_results?tic=198537349">details</a></td>
#     </tr>
#     <tr>
#       <td id="T_af507_row2_col0" class="data row2 col0" ><img src="https://panoptes-uploads.zooniverse.org/subject_location/f5720a50-965b-4413-9a26-9dc97b0ab155.png"></td>
#       <td id="T_af507_row2_col1" class="data row2 col1" ><a target="_exofop" href="https://exofop.ipac.caltech.edu/tess/target.php?id=281581467">281581467</a></td>
#       <td id="T_af507_row2_col2" class="data row2 col2" ><a target="_pht" href="https://www.zooniverse.org/projects/nora-dot-eisner/planet-hunters-tess/talk/subjects/60853074">60853074</a></td>
#       <td id="T_af507_row2_col3" class="data row2 col3" >F</td>
#       <td id="T_af507_row2_col4" class="data row2 col4" >7</td>
#       <td id="T_af507_row2_col5" class="data row2 col5" ><a target="_simbad" href="https://simbad.u-strasbg.fr/simbad/sim-basic?Ident=TYC 8911-718-1">TYC 8911-718-1</a></td>
#       <td id="T_af507_row2_col6" class="data row2 col6" ></td>
#       <td id="T_af507_row2_col7" class="data row2 col7" >-</td>
#       <td id="T_af507_row2_col8" class="data row2 col8" ><a target="_vsx" href="https://www.aavso.org/vsx/index.php?view=detail.top&oid=838559">838559</a></td>
#       <td id="T_af507_row2_col9" class="data row2 col9" >ROT:</td>
#       <td id="T_af507_row2_col10" class="data row2 col10" >F</td>
#       <td id="T_af507_row2_col11" class="data row2 col11" >nan</td>
#       <td id="T_af507_row2_col12" class="data row2 col12" >J074356.31-602347.0</td>
#       <td id="T_af507_row2_col13" class="data row2 col13" ><a target="_asas_sn" href="https://asas-sn.osu.edu/variables/AP39600700">details</a></td>
#       <td id="T_af507_row2_col14" class="data row2 col14" >VAR</td>
#       <td id="T_af507_row2_col15" class="data row2 col15" >0.000000</td>
#       <td id="T_af507_row2_col16" class="data row2 col16" ><a target="_tesseb" href="http://tessebs.villanova.edu/search_results?tic=281581467">details</a></td>
#     </tr>
#     <tr>
#       <td id="T_af507_row3_col0" class="data row3 col0" ><img src="https://panoptes-uploads.zooniverse.org/subject_location/342393b8-983f-4c87-9a08-38285f7a361e.png"></td>
#       <td id="T_af507_row3_col1" class="data row3 col1" ><a target="_exofop" href="https://exofop.ipac.caltech.edu/tess/target.php?id=4200337">4200337</a></td>
#       <td id="T_af507_row3_col2" class="data row3 col2" ><a target="_pht" href="https://www.zooniverse.org/projects/nora-dot-eisner/planet-hunters-tess/talk/subjects/56365918">56365918</a></td>
#       <td id="T_af507_row3_col3" class="data row3 col3" >F</td>
#       <td id="T_af507_row3_col4" class="data row3 col4" >6</td>
#       <td id="T_af507_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_af507_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_af507_row3_col7" class="data

# %%
dashboard_utils.display_details(
    tic_id=4200337, 
    type="tic_meta",
    brief=True,
)
plt.close(1);  # hide the plot outside the grid
# Out:
# GridBox(children=(Output(layout=Layout(border='1px dotted gray')), Output(layout=Layout(border='1px dotted gra…
